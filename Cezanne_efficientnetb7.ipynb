# %% [markdown]
# __Libraries__

# %%
import os
import shutil
import random
from collections import Counter
import numpy as np
import itertools
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Activation, Dense
import tensorflow as tf
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %% [markdown]
# __Convolutional Neural Network Setup (EfficientNetB7)__

# %%
file_location = os.getcwd()

train_path = file_location+"/data/train"
valid_path = file_location+"/data/valid"
test_path = file_location+"/data/test"
test_TI_SD1_path = file_location+"/data/TISD1"
test_TI_SD2_path = file_location+"/data/TISD2"
test_TI_SD3_path = file_location+"/data/TISD3"
test_TI_SD4_path = file_location+"/data/TISD4"

# %%
train_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=train_path, target_size=(224,224), batch_size=10)

valid_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=valid_path, target_size=(224,224), batch_size=10)

test_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=test_path,target_size=(224,224), batch_size=10, shuffle=False)

TISD1_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=test_TI_SD1_path,target_size=(224,224), batch_size=10, shuffle=False)

TISD2_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=test_TI_SD2_path,target_size=(224,224), batch_size=10, shuffle=False)

TISD3_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=test_TI_SD3_path,target_size=(224,224), batch_size=10, shuffle=False)

TISD4_batches = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet_v2.preprocess_input).flow_from_directory(directory=test_TI_SD4_path,target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 330 images belonging to 5 classes.
# Found 75 images belonging to 5 classes.
# Found 25 images belonging to 5 classes.
# Found 100 images belonging to 1 classes.
# Found 100 images belonging to 1 classes.
# Found 100 images belonging to 1 classes.
# Found 100 images belonging to 1 classes.

# %%
efficientnetb7 = tf.keras.applications.efficientnet.EfficientNetB7()
#efficientnetb7.summary()

# %%
x = efficientnetb7.layers[-2].output
output = Dense(units=5, activation="softmax")(x)

# %%
model = Model(inputs=efficientnetb7.input, outputs=output)

# %%
for layer in model.layers[:-23]:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 600, 600, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 600, 600, 3)  0           ['input_2[0][0]']
#
#  normalization_1 (Normalization  (None, 600, 600, 3)  7          ['rescaling_2[0][0]']
#  )
#
#  rescaling_3 (Rescaling)        (None, 600, 600, 3)  0           ['normalization_1[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 601, 601, 3)  0           ['rescaling_3[0][0]']
#
#  stem_conv (Conv2D)             (None, 300, 300, 64  1728        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 300, 300, 64  256         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 300, 300, 64  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 300, 300, 64  576        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 300, 300, 64  256        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 300, 300, 64  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 300, 300, 64  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 300, 300, 32  2048        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 300, 300, 32  288        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 300, 300, 32  128        ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 300, 300, 32  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 300, 300, 32  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 300, 300, 32  1024        ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 300, 300, 32  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 300, 300, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 300, 300, 32  288        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 300, 300, 32  128        ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 300, 300, 32  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 300, 300, 32  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 300, 300, 32  1024        ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 300, 300, 32  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 300, 300, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 300, 300, 32  288        ['block1c_add[0][0]']
#  D)                             )
#
#  block1d_bn (BatchNormalization  (None, 300, 300, 32  128        ['block1d_dwconv[0][0]']
#  )                              )
#
#  block1d_activation (Activation  (None, 300, 300, 32  0          ['block1d_bn[0][0]']
#  )                              )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 300, 300, 32  0           ['block1d_activation[0][0]',
#                                 )                                 'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 300, 300, 32  1024        ['block1d_se_excite[0][0]']
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 300, 300, 32  128        ['block1d_project_conv[0][0]']
#  lization)                      )
#
#  block1d_drop (Dropout)         (None, 300, 300, 32  0           ['block1d_project_bn[0][0]']
#                                 )
#
#  block1d_add (Add)              (None, 300, 300, 32  0           ['block1d_drop[0][0]',
#                                 )                                 'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 300, 300, 19  6144        ['block1d_add[0][0]']
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 300, 300, 19  768        ['block2a_expand_conv[0][0]']
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 300, 300, 19  0          ['block2a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 301, 301, 19  0          ['block2a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 150, 150, 19  1728       ['block2a_dwconv_pad[0][0]']
#  D)                             2)
#
#  block2a_bn (BatchNormalization  (None, 150, 150, 19  768        ['block2a_dwconv[0][0]']
#  )                              2)
#
#  block2a_activation (Activation  (None, 150, 150, 19  0          ['block2a_bn[0][0]']
#  )                              2)
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 150, 150, 19  0           ['block2a_activation[0][0]',
#                                 2)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 150, 150, 48  9216        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2a_project_bn[0][0]']
#                                 8)
#
#  block2b_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2b_expand_conv[0][0]']
#  ization)                       8)
#
#  block2b_expand_activation (Act  (None, 150, 150, 28  0          ['block2b_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2b_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2b_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2b_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2b_dwconv[0][0]']
#  )                              8)
#
#  block2b_activation (Activation  (None, 150, 150, 28  0          ['block2b_bn[0][0]']
#  )                              8)
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2b_activation[0][0]',
#                                 8)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 150, 150, 48  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 150, 150, 48  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2b_add[0][0]']
#                                 8)
#
#  block2c_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2c_expand_conv[0][0]']
#  ization)                       8)
#
#  block2c_expand_activation (Act  (None, 150, 150, 28  0          ['block2c_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2c_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2c_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2c_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2c_dwconv[0][0]']
#  )                              8)
#
#  block2c_activation (Activation  (None, 150, 150, 28  0          ['block2c_bn[0][0]']
#  )                              8)
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2c_activation[0][0]',
#                                 8)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 150, 150, 48  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 150, 150, 48  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2c_add[0][0]']
#                                 8)
#
#  block2d_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2d_expand_conv[0][0]']
#  ization)                       8)
#
#  block2d_expand_activation (Act  (None, 150, 150, 28  0          ['block2d_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2d_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2d_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2d_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2d_dwconv[0][0]']
#  )                              8)
#
#  block2d_activation (Activation  (None, 150, 150, 28  0          ['block2d_bn[0][0]']
#  )                              8)
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2d_activation[0][0]',
#                                 8)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 150, 150, 48  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 150, 150, 48  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2d_add[0][0]']
#                                 8)
#
#  block2e_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2e_expand_conv[0][0]']
#  ization)                       8)
#
#  block2e_expand_activation (Act  (None, 150, 150, 28  0          ['block2e_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2e_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2e_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2e_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2e_dwconv[0][0]']
#  )                              8)
#
#  block2e_activation (Activation  (None, 150, 150, 28  0          ['block2e_bn[0][0]']
#  )                              8)
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2e_activation[0][0]',
#                                 8)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 150, 150, 48  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 150, 150, 48  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2e_add[0][0]']
#                                 8)
#
#  block2f_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2f_expand_conv[0][0]']
#  ization)                       8)
#
#  block2f_expand_activation (Act  (None, 150, 150, 28  0          ['block2f_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2f_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2f_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2f_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2f_dwconv[0][0]']
#  )                              8)
#
#  block2f_activation (Activation  (None, 150, 150, 28  0          ['block2f_bn[0][0]']
#  )                              8)
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2f_activation[0][0]',
#                                 8)                                'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2f_se_excite[0][0]']
#                                 )
#
#  block2f_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2f_project_conv[0][0]']
#  lization)                      )
#
#  block2f_drop (Dropout)         (None, 150, 150, 48  0           ['block2f_project_bn[0][0]']
#                                 )
#
#  block2f_add (Add)              (None, 150, 150, 48  0           ['block2f_drop[0][0]',
#                                 )                                 'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2f_add[0][0]']
#                                 8)
#
#  block2g_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block2g_expand_conv[0][0]']
#  ization)                       8)
#
#  block2g_expand_activation (Act  (None, 150, 150, 28  0          ['block2g_expand_bn[0][0]']
#  ivation)                       8)
#
#  block2g_dwconv (DepthwiseConv2  (None, 150, 150, 28  2592       ['block2g_expand_activation[0][0]
#  D)                             8)                               ']
#
#  block2g_bn (BatchNormalization  (None, 150, 150, 28  1152       ['block2g_dwconv[0][0]']
#  )                              8)
#
#  block2g_activation (Activation  (None, 150, 150, 28  0          ['block2g_bn[0][0]']
#  )                              8)
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 150, 150, 28  0           ['block2g_activation[0][0]',
#                                 8)                                'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 150, 150, 48  13824       ['block2g_se_excite[0][0]']
#                                 )
#
#  block2g_project_bn (BatchNorma  (None, 150, 150, 48  192        ['block2g_project_conv[0][0]']
#  lization)                      )
#
#  block2g_drop (Dropout)         (None, 150, 150, 48  0           ['block2g_project_bn[0][0]']
#                                 )
#
#  block2g_add (Add)              (None, 150, 150, 48  0           ['block2g_drop[0][0]',
#                                 )                                 'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 150, 150, 28  13824       ['block2g_add[0][0]']
#                                 8)
#
#  block3a_expand_bn (BatchNormal  (None, 150, 150, 28  1152       ['block3a_expand_conv[0][0]']
#  ization)                       8)
#
#  block3a_expand_activation (Act  (None, 150, 150, 28  0          ['block3a_expand_bn[0][0]']
#  ivation)                       8)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 153, 153, 28  0          ['block3a_expand_activation[0][0]
#  g2D)                           8)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 75, 75, 288)  7200       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 75, 75, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 75, 75, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 75, 75, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 75, 75, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 75, 75, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 75, 75, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 75, 75, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 75, 75, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
# ...
#
#  block7a_bn (BatchNormalization  (None, 19, 19, 2304  9216       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 19, 19, 2304  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 2304)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 19, 19, 2304  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 19, 19, 640)  1474560     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 19, 19, 3840  2457600     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 19, 19, 3840  15360      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 19, 19, 3840  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 19, 19, 3840  34560      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 19, 19, 3840  15360      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 19, 19, 3840  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3840)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7b_se_reduce[0][0]']
#  block7b_se_excite (Multiply)   (None, 19, 19, 3840  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 19, 19, 640)  2457600     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 19, 19, 640)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 19, 19, 640)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 19, 19, 3840  2457600     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 19, 19, 3840  15360      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 19, 19, 3840  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 19, 19, 3840  34560      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 19, 19, 3840  15360      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 19, 19, 3840  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3840)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 19, 19, 3840  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 19, 19, 640)  2457600     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 19, 19, 640)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 19, 19, 640)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 19, 19, 3840  2457600     ['block7c_add[0][0]']
#                                 )
#
#  block7d_expand_bn (BatchNormal  (None, 19, 19, 3840  15360      ['block7d_expand_conv[0][0]']
#  ization)                       )
#
#  block7d_expand_activation (Act  (None, 19, 19, 3840  0          ['block7d_expand_bn[0][0]']
#  ivation)                       )
#
#  block7d_dwconv (DepthwiseConv2  (None, 19, 19, 3840  34560      ['block7d_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7d_bn (BatchNormalization  (None, 19, 19, 3840  15360      ['block7d_dwconv[0][0]']
#  )                              )
#
#  block7d_activation (Activation  (None, 19, 19, 3840  0          ['block7d_bn[0][0]']
#  )                              )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 19, 19, 3840  0           ['block7d_activation[0][0]',
#                                 )                                 'block7d_se_expand[0][0]']
#  block7d_project_conv (Conv2D)  (None, 19, 19, 640)  2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 19, 19, 640)  2560       ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 19, 19, 640)  0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 19, 19, 640)  0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 19, 19, 2560  1638400     ['block7d_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 19, 19, 2560  10240       ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 19, 19, 2560  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 2560)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 2560)         0           ['avg_pool[0][0]']
#
#  dense_3 (Dense)                (None, 5)            12805       ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 64,110,492
# Trainable params: 7,855,525
# Non-trainable params: 56,254,967
# __________________________________________________________________________________________________

# %% [markdown]
# __Train model__

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(x=train_batches, validation_data=valid_batches, epochs=50, verbose = 2)
# Out:
# Epoch 1/50
# 33/33 - 180s - loss: 1.3848 - accuracy: 0.4424 - val_loss: 1.1750 - val_accuracy: 0.5600 - 180s/epoch - 5s/step
# Epoch 2/50
# 33/33 - 269s - loss: 0.9255 - accuracy: 0.6939 - val_loss: 1.0072 - val_accuracy: 0.6533 - 269s/epoch - 8s/step
# Epoch 3/50
# 33/33 - 279s - loss: 0.7501 - accuracy: 0.7697 - val_loss: 0.9041 - val_accuracy: 0.6933 - 279s/epoch - 8s/step
# Epoch 4/50
# 33/33 - 237s - loss: 0.5863 - accuracy: 0.8485 - val_loss: 0.8465 - val_accuracy: 0.6933 - 237s/epoch - 7s/step
# Epoch 5/50
# 33/33 - 230s - loss: 0.4658 - accuracy: 0.8909 - val_loss: 0.8014 - val_accuracy: 0.7067 - 230s/epoch - 7s/step
# Epoch 6/50
# 33/33 - 200s - loss: 0.3350 - accuracy: 0.9333 - val_loss: 0.7426 - val_accuracy: 0.6800 - 200s/epoch - 6s/step
# Epoch 7/50
# 33/33 - 303s - loss: 0.2432 - accuracy: 0.9485 - val_loss: 0.7162 - val_accuracy: 0.7200 - 303s/epoch - 9s/step
# Epoch 8/50
# 33/33 - 279s - loss: 0.2164 - accuracy: 0.9515 - val_loss: 0.6815 - val_accuracy: 0.7067 - 279s/epoch - 8s/step
# Epoch 9/50
# 33/33 - 206s - loss: 0.1900 - accuracy: 0.9545 - val_loss: 0.6753 - val_accuracy: 0.7067 - 206s/epoch - 6s/step
# Epoch 10/50
# 33/33 - 143s - loss: 0.1966 - accuracy: 0.9424 - val_loss: 0.7021 - val_accuracy: 0.6933 - 143s/epoch - 4s/step
# Epoch 11/50
# 33/33 - 145s - loss: 0.1363 - accuracy: 0.9697 - val_loss: 0.7221 - val_accuracy: 0.6800 - 145s/epoch - 4s/step
# Epoch 12/50
# 33/33 - 141s - loss: 0.1492 - accuracy: 0.9667 - val_loss: 0.6503 - val_accuracy: 0.6800 - 141s/epoch - 4s/step
# Epoch 13/50
# 33/33 - 139s - loss: 0.1241 - accuracy: 0.9727 - val_loss: 0.6966 - val_accuracy: 0.6800 - 139s/epoch - 4s/step
# Epoch 14/50
# 33/33 - 138s - loss: 0.1251 - accuracy: 0.9758 - val_loss: 0.7010 - val_accuracy: 0.7067 - 138s/epoch - 4s/step
# Epoch 15/50
# 33/33 - 139s - loss: 0.0858 - accuracy: 0.9848 - val_loss: 0.6718 - val_accuracy: 0.7200 - 139s/epoch - 4s/step
# Epoch 16/50
# 33/33 - 138s - loss: 0.1140 - accuracy: 0.9788 - val_loss: 0.6644 - val_accuracy: 0.7067 - 138s/epoch - 4s/step
# Epoch 17/50
# 33/33 - 138s - loss: 0.0875 - accuracy: 0.9818 - val_loss: 0.6411 - val_accuracy: 0.7200 - 138s/epoch - 4s/step
# Epoch 18/50
# 33/33 - 138s - loss: 0.0863 - accuracy: 0.9818 - val_loss: 0.6838 - val_accuracy: 0.6933 - 138s/epoch - 4s/step
# Epoch 19/50
# 33/33 - 138s - loss: 0.1427 - accuracy: 0.9545 - val_loss: 0.6888 - val_accuracy: 0.6933 - 138s/epoch - 4s/step
# Epoch 20/50
# 33/33 - 138s - loss: 0.0948 - accuracy: 0.9727 - val_loss: 0.6593 - val_accuracy: 0.7067 - 138s/epoch - 4s/step
# Epoch 21/50
# 33/33 - 138s - loss: 0.1024 - accuracy: 0.9667 - val_loss: 0.6468 - val_accuracy: 0.7200 - 138s/epoch - 4s/step
# Epoch 22/50
# 33/33 - 139s - loss: 0.0804 - accuracy: 0.9818 - val_loss: 0.6506 - val_accuracy: 0.6800 - 139s/epoch - 4s/step
# Epoch 23/50
# 33/33 - 139s - loss: 0.0970 - accuracy: 0.9667 - val_loss: 0.7170 - val_accuracy: 0.6933 - 139s/epoch - 4s/step
# Epoch 24/50
# 33/33 - 139s - loss: 0.0888 - accuracy: 0.9758 - val_loss: 0.6931 - val_accuracy: 0.6933 - 139s/epoch - 4s/step
# Epoch 25/50
# 33/33 - 138s - loss: 0.0784 - accuracy: 0.9939 - val_loss: 0.7526 - val_accuracy: 0.6800 - 138s/epoch - 4s/step
# Epoch 26/50
# 33/33 - 139s - loss: 0.0900 - accuracy: 0.9727 - val_loss: 0.7263 - val_accuracy: 0.7200 - 139s/epoch - 4s/step
# Epoch 27/50
# 33/33 - 138s - loss: 0.0876 - accuracy: 0.9667 - val_loss: 0.7256 - val_accuracy: 0.7333 - 138s/epoch - 4s/step
# Epoch 28/50
# 33/33 - 141s - loss: 0.0614 - accuracy: 0.9818 - val_loss: 0.7331 - val_accuracy: 0.7200 - 141s/epoch - 4s/step
# Epoch 29/50
# 33/33 - 139s - loss: 0.0640 - accuracy: 0.9848 - val_loss: 0.7363 - val_accuracy: 0.6800 - 139s/epoch - 4s/step
# Epoch 30/50
# 33/33 - 139s - loss: 0.0622 - accuracy: 0.9818 - val_loss: 0.7194 - val_accuracy: 0.7067 - 139s/epoch - 4s/step
# Epoch 31/50
# 33/33 - 139s - loss: 0.0647 - accuracy: 0.9788 - val_loss: 0.7042 - val_accuracy: 0.7333 - 139s/epoch - 4s/step
# Epoch 32/50
# 33/33 - 139s - loss: 0.0860 - accuracy: 0.9697 - val_loss: 0.7420 - val_accuracy: 0.7067 - 139s/epoch - 4s/step
# Epoch 33/50
# 33/33 - 139s - loss: 0.0637 - accuracy: 0.9848 - val_loss: 0.7912 - val_accuracy: 0.7467 - 139s/epoch - 4s/step
# Epoch 34/50
# 33/33 - 139s - loss: 0.0591 - accuracy: 0.9909 - val_loss: 0.7455 - val_accuracy: 0.7067 - 139s/epoch - 4s/step
# Epoch 35/50
# 33/33 - 141s - loss: 0.0555 - accuracy: 0.9939 - val_loss: 0.7571 - val_accuracy: 0.7067 - 141s/epoch - 4s/step
# Epoch 36/50
# 33/33 - 139s - loss: 0.0707 - accuracy: 0.9727 - val_loss: 0.8028 - val_accuracy: 0.7200 - 139s/epoch - 4s/step
# Epoch 37/50
# 33/33 - 139s - loss: 0.0610 - accuracy: 0.9848 - val_loss: 0.8462 - val_accuracy: 0.7467 - 139s/epoch - 4s/step
# Epoch 38/50
# 33/33 - 139s - loss: 0.0567 - accuracy: 0.9879 - val_loss: 0.8151 - val_accuracy: 0.7333 - 139s/epoch - 4s/step
# Epoch 39/50
# 33/33 - 139s - loss: 0.0698 - accuracy: 0.9727 - val_loss: 0.8132 - val_accuracy: 0.7067 - 139s/epoch - 4s/step
# Epoch 40/50
# 33/33 - 139s - loss: 0.0491 - accuracy: 0.9879 - val_loss: 0.7709 - val_accuracy: 0.7200 - 139s/epoch - 4s/step
# Epoch 41/50
# 33/33 - 139s - loss: 0.0551 - accuracy: 0.9909 - val_loss: 0.7642 - val_accuracy: 0.7333 - 139s/epoch - 4s/step
# Epoch 42/50
# 33/33 - 139s - loss: 0.0613 - accuracy: 0.9909 - val_loss: 0.7974 - val_accuracy: 0.7467 - 139s/epoch - 4s/step
# Epoch 43/50
# 33/33 - 138s - loss: 0.0439 - accuracy: 0.9879 - val_loss: 0.7789 - val_accuracy: 0.7733 - 138s/epoch - 4s/step
# Epoch 44/50
# 33/33 - 138s - loss: 0.0393 - accuracy: 0.9909 - val_loss: 0.7844 - val_accuracy: 0.7600 - 138s/epoch - 4s/step
# Epoch 45/50
# 33/33 - 139s - loss: 0.0456 - accuracy: 0.9909 - val_loss: 0.7751 - val_accuracy: 0.7467 - 139s/epoch - 4s/step
# Epoch 46/50
# 33/33 - 139s - loss: 0.0368 - accuracy: 0.9970 - val_loss: 0.7922 - val_accuracy: 0.7333 - 139s/epoch - 4s/step
# Epoch 47/50
# 33/33 - 139s - loss: 0.0435 - accuracy: 0.9909 - val_loss: 0.8658 - val_accuracy: 0.7067 - 139s/epoch - 4s/step
# Epoch 48/50
# 33/33 - 139s - loss: 0.0196 - accuracy: 0.9970 - val_loss: 0.7832 - val_accuracy: 0.7467 - 139s/epoch - 4s/step
# Epoch 49/50
# 33/33 - 139s - loss: 0.0435 - accuracy: 0.9848 - val_loss: 0.7515 - val_accuracy: 0.7600 - 139s/epoch - 4s/step
# Epoch 50/50
# 33/33 - 139s - loss: 0.0262 - accuracy: 0.9970 - val_loss: 0.7560 - val_accuracy: 0.7467 - 139s/epoch - 4s/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# __Predictions for Test Data__

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title="Confusion Matrix", cmap=plt.cm.Blues):
    plt.imshow(cm,interpolation="nearest", cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm=cm.astype("float")/cm.sum(axis=1)[:, np.newaxis]
        print("Normalized Confusion Matrix")
    else:
        print("Confusion Matrix without normalization")
    
    print(cm)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,i,cm[i,j],
                 horizontalalignment="center",
                 color="white" if cm[i,j]>thresh else "black")
    
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %%
test_labels = test_batches.classes
predictions = model.predict(x=test_batches, verbose = 0)

# %%
cm = confusion_matrix(y_true=test_labels, y_pred=predictions.argmax(axis=1))
#test_batches.class_indices
cm_plot_labels = ["0","1","2","3","4"]
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title="Confusion Matrix")
# Out:
# Confusion Matrix without normalization
# [[3 0 0 2 0]
#  [2 2 1 0 0]
#  [0 0 5 0 0]
#  [0 0 0 5 0]
#  [0 0 0 1 4]]

# %% [markdown]
# __Predictions for Textual Inversion Trained Stable Diffusion 2 generated data__

# %%
#TISD1 were images created by Stable Diffusion with prompt: "painting in the style of <Cezanne>"
TISD1_labels = TISD1_batches.classes

# %%
predictions = model.predict(x=TISD1_batches, verbose = 0)
Counter(predictions.argmax(axis=1))
# Out:
# Counter({0: 35, 1: 39, 4: 16, 3: 10})

# %%
fig = plt.figure()
 
plt.bar(Counter(predictions.argmax(axis=1)).keys(), Counter(predictions.argmax(axis=1)).values())
 
plt.xlabel("Categories")
plt.ylabel("Generated Images")
plt.title("Predictions for Textual Inversion Generated Images")
plt.show()

# %%
predictions
# Out:
# array([[6.24276638e-01, 1.31195426e-01, 9.27339494e-03, 2.25870594e-01,
#         9.38396901e-03],
#        [3.62219512e-01, 3.94395292e-01, 4.46309149e-02, 1.65223539e-01,
#         3.35307531e-02],
#        [3.06813419e-01, 6.49505734e-01, 5.01277251e-03, 3.48643549e-02,
#         3.80375283e-03],
#        [1.56440303e-01, 1.01320008e-02, 3.47572416e-02, 1.01657398e-02,
#         7.88504779e-01],
#        [3.85155171e-01, 5.54346263e-01, 9.84196085e-03, 2.28558984e-02,
#         2.78007835e-02],
#        [8.81930411e-01, 9.30758640e-02, 6.73331972e-03, 1.08198146e-03,
#         1.71784535e-02],
#        [8.42129588e-02, 8.38257074e-01, 4.58473787e-02, 6.91331318e-03,
#         2.47692224e-02],
#        [5.69702208e-01, 2.74324358e-01, 2.12415420e-02, 2.66502425e-03,
#         1.32066846e-01],
#        [3.91629785e-01, 1.55191422e-01, 1.14574395e-01, 2.62073904e-01,
#         7.65304938e-02],
#        [3.35668534e-01, 3.59377444e-01, 1.39993336e-02, 6.06585257e-02,
#         2.30296195e-01],
#        [2.50646383e-01, 7.61461630e-02, 3.97155853e-03, 8.67562776e-04,
#         6.68368340e-01],
#        [5.43947592e-02, 9.07685328e-03, 1.01672998e-02, 9.08088863e-01,
#         1.82721615e-02],
#        [2.24981569e-02, 4.10017610e-01, 8.67691543e-03, 5.58214247e-01,
#         5.92999102e-04],
#        [8.79263759e-01, 2.01173164e-02, 1.68678933e-03, 9.62785706e-02,
#         2.65348470e-03],
#        [7.53494263e-01, 1.17284350e-01, 6.08715117e-02, 1.12091647e-02,
#         5.71406856e-02],
#        [9.88898054e-03, 5.25341630e-01, 4.53444954e-04, 1.84015244e-01,
#         2.80300647e-01],
#        [8.50827619e-02, 9.13718879e-01, 6.90325745e-04, 7.97557368e-05,
#         4.28243016e-04],
#        [7.29971901e-02, 1.44461682e-02, 1.36260157e-02, 1.13619804e-01,
#         7.85310745e-01],
#        [2.68135071e-02, 9.53245938e-01, 1.48303807e-02, 5.09697339e-03,
#         1.31533297e-05],
#        [3.90915982e-02, 4.34006423e-01, 1.25161394e-01, 8.31039995e-02,
#         3.18636566e-01],
#        [7.74593949e-01, 1.55614510e-01, 2.34449115e-02, 1.19326345e-03,
#         4.51533422e-02],
#        [8.70028794e-01, 3.42690088e-02, 4.99033444e-02, 1.44085754e-02,
#         3.13902162e-02],
#        [7.32919395e-01, 1.37179298e-02, 1.71120781e-02, 1.60000678e-02,
#         2.20250517e-01],
#        [2.46862948e-01, 2.15425789e-01, 1.92455817e-02, 4.78969306e-01,
#         3.94963361e-02],
#        [8.90669644e-01, 3.52789438e-03, 1.87856180e-03, 1.94866359e-02,
#         5.00833876e-02],
#        [8.08863282e-01, 1.10728145e-01, 1.43038463e-02, 5.15508577e-02,
#         1.45538328e-02],
#        [1.33484647e-01, 7.64095247e-01, 1.23545015e-02, 5.82551770e-02,
#         3.18103991e-02],
#        [8.03678870e-01, 3.68820243e-02, 3.48636531e-03, 1.47932127e-01,
#         8.02061334e-03],
#        [1.09049313e-01, 7.62709044e-03, 1.15014706e-03, 1.21431274e-03,
#         8.80959094e-01],
#        [8.67159605e-01, 7.30443224e-02, 1.06491027e-02, 3.20883170e-02,
#         1.70585513e-02],
#        [5.45339752e-03, 2.72759944e-02, 3.55424592e-04, 1.95550849e-03,
#         9.64959681e-01],
#        [1.76992565e-01, 5.81963480e-01, 4.90857521e-03, 2.34188154e-01,
#         1.94731180e-03],
#        [1.04136385e-01, 3.91321816e-02, 2.65613403e-02, 3.98761034e-01,
#         4.31409091e-01],
#        [2.54903942e-01, 1.35405898e-01, 1.43112287e-01, 1.18488036e-02,
#         4.54729021e-01],
#        [1.52428458e-02, 5.58800995e-01, 1.78747084e-02, 3.72743934e-01,
#         3.53374779e-02],
#        [7.61776030e-01, 6.13224134e-02, 2.04619602e-03, 5.16841486e-02,
#         1.23171210e-01],
#        [1.84615690e-03, 1.39985736e-02, 1.36519643e-03, 3.35398153e-03,
#         9.79436159e-01],
#        [9.21384692e-01, 2.12873835e-02, 3.95137258e-03, 9.00985848e-04,
#         5.24754375e-02],
#        [3.06186736e-01, 3.98840755e-01, 2.03416198e-02, 8.28601420e-03,
#         2.66344875e-01],
#        [4.89351243e-01, 5.07378817e-01, 2.22276969e-04, 1.31686835e-03,
#         1.73072843e-03],
#        [9.95543420e-01, 1.28131581e-03, 1.72408053e-03, 5.33842132e-04,
#         9.17396042e-04],
#        [3.86110187e-01, 1.58587709e-01, 8.31491966e-03, 1.30049422e-01,
#         3.16937774e-01],
#        [7.51300827e-02, 6.45211995e-01, 1.87271945e-02, 2.43015051e-01,
#         1.79158133e-02],
#        [4.16503131e-01, 2.08211951e-02, 1.24303633e-02, 7.59980381e-02,
#         4.74247277e-01]], dtype=float32)

# %%
#TISD2 were images created by Stable Diffusion with prompt: "landscape painting in the style of <Cezanne>"
TISD2_labels = TISD2_batches.classes

# %%
predictions = model.predict(x=TISD2_batches, verbose = 0)
Counter(predictions.argmax(axis=1))
# Out:
# Counter({0: 25, 3: 41, 4: 9, 1: 25})

# %%
fig = plt.figure()
 
plt.bar(Counter(predictions.argmax(axis=1)).keys(), Counter(predictions.argmax(axis=1)).values())
 
plt.xlabel("Categories")
plt.ylabel("Generated Images")
plt.title("Predictions for Textual Inversion Generated Images")
plt.show()

# %%
predictions
# Out:
# array([[3.69672894e-01, 6.51837364e-02, 4.40606251e-02, 3.37711543e-01,
#         1.83371186e-01],
#        [3.34579386e-02, 4.98187803e-02, 4.91856597e-03, 9.04859066e-01,
#         6.94574229e-03],
#        [2.17984430e-02, 8.22674781e-02, 6.81130216e-03, 8.66707265e-01,
#         2.24155951e-02],
#        [1.45346582e-01, 1.22287624e-01, 7.56285489e-02, 6.47053897e-01,
#        [5.90180680e-02, 3.40447277e-01, 4.71918285e-03, 3.78922999e-01,
#         2.16892466e-01],
#        [7.43317744e-03, 1.48466472e-02, 2.59311637e-04, 9.16142941e-01,
#         6.13179877e-02],
#        [2.45256200e-01, 3.81401688e-01, 5.81344869e-03, 1.60433892e-02,
#         3.51485252e-01],
#        [2.01077104e-01, 5.13916075e-01, 1.79672744e-02, 1.07166842e-01,
#         1.59872681e-01],
#        [9.49684978e-02, 1.34209216e-01, 5.19125396e-03, 7.52851307e-01,
#         1.27796819e-02],
#        [2.51021355e-01, 2.93045968e-01, 4.01384709e-03, 1.45403177e-01,
#         3.06515723e-01],
#        [1.50423869e-01, 6.32798910e-01, 1.78416539e-02, 1.53681606e-01,
#         4.52539958e-02],
#        [4.55779880e-01, 2.72085488e-01, 1.03003252e-02, 2.41659269e-01,
#         2.01749727e-02],
#        [6.79265931e-02, 9.45437998e-02, 8.23498587e-04, 8.35679531e-01,
#         1.02659105e-03],
#        [1.54943407e-01, 5.75296819e-01, 2.44146228e-01, 6.74587628e-03,
#         1.88676268e-02],
#        [1.10352496e-02, 9.46537495e-01, 3.19601633e-02, 7.54522765e-03,
#         2.92193564e-03],
#        [6.66052461e-01, 1.78897679e-01, 5.49165066e-03, 3.34798507e-02,
#         1.16078384e-01],
#        [3.38030495e-02, 9.80879813e-02, 7.50862248e-03, 7.81618118e-01,
#         7.89821446e-02]], dtype=float32)

# %%
#TISD3 were images created by Stable Diffusion with prompt: "painting of the Provence in the style of <Cézanne>"
TISD3_labels = TISD3_batches.classes

# %%
predictions = model.predict(x=TISD3_batches, verbose = 0)
Counter(predictions.argmax(axis=1))
# Out:
# Counter({3: 14, 4: 16, 0: 45, 1: 23, 2: 2})

# %%
fig = plt.figure()
 
plt.bar(Counter(predictions.argmax(axis=1)).keys(), Counter(predictions.argmax(axis=1)).values())
 
plt.xlabel("Categories")
plt.ylabel("Generated Images")
plt.title("Predictions for Textual Inversion Generated Images")
plt.show()

# %%
predictions
# Out:
# array([[6.96096346e-02, 2.30627298e-01, 1.56788435e-02, 6.80372059e-01,
#         3.71217309e-03],
#        [3.57727379e-01, 6.93365037e-02, 3.41519751e-02, 6.17397912e-02,
#         4.77044374e-01],
#        [9.29464042e-01, 1.64261945e-02, 3.43636144e-03, 4.42234287e-03,
#         4.62510698e-02],
#        [6.67277098e-01, 8.04486871e-02, 1.47292763e-03, 2.50164594e-04,
#         2.50551045e-01],
#        [3.12296301e-01, 5.41269720e-01, 2.00091023e-03, 5.11106988e-03,
#         1.39321968e-01],
#        [6.60125256e-01, 2.32570007e-01, 1.72191467e-02, 2.65335720e-02,
#         6.35520741e-02],
#        [1.91182997e-02, 9.48143005e-01, 2.54177973e-02, 6.04271097e-03,
#         1.27821928e-03],
#        [8.12951326e-02, 2.59634525e-01, 6.30667880e-02, 5.90449750e-01,
#         5.55380201e-03],
#        [2.47888848e-01, 4.39650565e-02, 5.42807439e-03, 2.95158066e-02,
#         6.73202217e-01],
#        [8.47555816e-01, 1.25728026e-01, 9.32384282e-03, 1.38673419e-02,
#         3.11180297e-02],
#        [8.34633887e-01, 6.22895733e-03, 2.20775120e-02, 2.21769186e-03,
#         1.34842038e-01],
#        [2.93335579e-02, 2.08360888e-03, 3.06062889e-03, 1.63331410e-04,
#         9.65358913e-01],
#        [1.15857888e-02, 9.80905890e-01, 7.02552730e-04, 5.26639742e-05,
#         6.75307959e-03],
#        [5.06542981e-01, 3.26416850e-01, 1.56792030e-01, 8.16370081e-03,
#         2.08445918e-03],
#        [6.58539951e-01, 3.18874806e-01, 8.03267956e-03, 3.27035342e-03,
#         1.12821329e-02],
#        [5.44839263e-01, 2.15500265e-01, 6.34712949e-02, 1.14374407e-01,
#         6.18148297e-02]], dtype=float32)

# %%
#TISD4 were images created by Stable Diffusion with prompt: "painting of Mont Saint Victoire in the style of <Cézanne>"
TISD4_labels = TISD4_batches.classes

# %%
predictions = model.predict(x=TISD4_batches, verbose = 0)
Counter(predictions.argmax(axis=1))
# Out:
# Counter({3: 35, 1: 27, 0: 27, 4: 8, 2: 3})

# %%
fig = plt.figure()
 
plt.bar(Counter(predictions.argmax(axis=1)).keys(), Counter(predictions.argmax(axis=1)).values())
 
plt.xlabel("Categories")
plt.ylabel("Generated Images")
plt.title("Predictions for Textual Inversion Generated Images")
plt.show()

# %%
predictions
# Out:
# array([[1.47058209e-02, 9.32980329e-03, 6.35701464e-03, 9.65809643e-01,
#         3.79764684e-03],
#        [1.46790445e-01, 8.10660958e-01, 2.38761469e-03, 2.50311214e-02,
#         1.51298009e-02],
#        [8.36137176e-01, 8.04304406e-02, 1.29655451e-02, 2.32409108e-02,
#         4.72259596e-02],
#        [9.61378157e-01, 1.13343075e-03, 3.29130096e-03, 2.37606862e-03,
#         3.18209827e-02],
#        [1.25419907e-02, 2.36949697e-01, 6.74786372e-03, 7.43011892e-01,
#         7.48579449e-04],
#        [2.54679233e-01, 2.54123770e-02, 5.42925252e-03, 1.56541258e-01,
#         5.57937920e-01],
#        [4.37141843e-02, 2.83200443e-02, 1.97127476e-04, 9.22025561e-01,
#         5.74311707e-03],
#        [9.72556174e-02, 2.84791082e-01, 1.74441095e-03, 6.12205744e-01,
#         4.00318252e-03],
#        [8.85609627e-01, 3.59122381e-02, 1.65329280e-03, 4.76865172e-02,
#         2.91382801e-02],
#        [6.83145463e-01, 5.91900796e-02, 1.03978813e-03, 1.00163780e-01,
#         1.56460911e-01],
#        [1.15043158e-02, 9.42665815e-01, 1.31183583e-02, 2.77255122e-02,
#         4.98590525e-03],
#        [1.23361222e-01, 6.19098604e-01, 2.07101732e-01, 2.55292710e-02,
#         2.49092318e-02],
#        [8.21412623e-01, 1.40392696e-02, 6.64976600e-04, 1.25297949e-01,
#         3.85852121e-02],
#        [1.62142627e-02, 6.92308173e-02, 7.02987425e-04, 9.13391113e-01,
#         4.60846873e-04],
#        [1.73415206e-02, 1.31385684e-01, 3.81480716e-02, 7.84175098e-01,
#         2.89495215e-02],
#        [4.44936194e-03, 7.71208882e-01, 8.80687207e-04, 2.16889217e-01,
#         6.57184701e-03],
